# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two trains start from the same station at the same time, one traveling east at 60 mph and the other traveling west at 40 mph, a bird starts flying from the first train toward the second at 90 mph. When it reaches the second train, it instantly turns around and flies back to the first train, continuing this back-and-forth flight until the trains meet. How far does the bird travel before the trains collide?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step.
#
# ### Given:
# - Two trains start from the same station at the same time.
# - Train A travels east at 60 mph.
# - Train B travels west at 40 mph.
# - A bird starts from the first train and flies toward the second train at 90 mph.
# - Each time the bird reaches a train, it instantly turns around and flies back toward the other train.
# - The bird continues flying back and forth until the two trains meet.
#
# ### Goal:
# Find the total distance the bird flies before the trains collide.
#
# ---
#
# ### Step 1: Find the time until the trains meet
#
# The trains are moving in opposite directions from the same point.
#
# - Relative speed of separation \( = 60 + 40 = 100 \text{ mph} \)
#
# Assuming the trains start at the same point (distance zero between them), but since they are moving apart, they will never collide if this was the setup. So, likely, the problem expects the trains to be **moving towards** each other, or the station represents the midpoint, and the trains move towards each other.
#
# But the problem states: "two trains **start from the same station at the same time**, one traveling east, other west."
#
# Normally if they move opposite directions from the same place, they move apart indefinitely and never meet.
#
# **It's likely the problem assumes the trains are moving towards each other starting at some distance apart.** Let me double-check the question:
#
# **The problem says:**
# > If two trains start from the same station at the same time, one traveling east at 60 mph and the other traveling west at 40 mph...
#
# Then the trains move away from each other and never meet.
#
# Is the problem possibly misstated?
#
# ---
#
# ### Common version of this problem:
#
# Two trains start at **different stations, \( D \) miles apart**, moving toward each other at speeds 60 mph and 40 mph. A bird flies back and forth in between at 90 mph.
#
# Given that the trains start \( D \) miles apart, the time until they meet is:
#
# \[
# t = \frac{D}{60 + 40} = \frac{D}{100} \text{ hours}
# \]
#
# The bird flies continuously at 90 mph during this time:
#
# \[
# \text{Distance bird flies} = 90 \times t = 90 \times \frac{D}{100} = \frac{9}{10} D
# \]
#
# ---
#
# ### So, the **key point here** is that the trains start from **different stations** a distance \( D \) apart.
#
# ---
#
# ### Summary:
#
# - Time until trains meet: \( t = \frac{D}{60 + 40} = \frac{D}{100} \) hours
# - Bird's speed: 90 mph
# - Bird's total distance: \( 90 \times t = \frac{9}{10} D \)
#
# ---
#
# ### Without the distance, we cannot get numerical value for bird's distance.
#
# ---
#
# ### Let's re-examine the question carefully:
#
# **Exact question:**
#
# > If two trains start from the same station at the same time, one traveling east at 60 mph and the other traveling west at 40 mph, a bird starts flying from the first train toward the second at 90 mph. When it reaches the second train, it instantly turns around and flies back to the first train, continuing this back-and-forth flight until the trains meet. How far does the bird travel before the trains collide?
#
# Because the trains start at the same station but go opposite directions at different speeds, they will never meet. Unless the problem means something else by "meet."
#
# ---
#
# ### Possible interpretation:
#
# Could it mean the trains start at the same station, but after some time, trains reverse direction and meet? Or a typo?
#
# Or maybe the bird flying towards the second train means the bird flies from eastbound train *behind* it to catch the other one moving west.
#
# ---
#
# ### **Alternative assumption:**
#
# If the trains move **toward each other**, suppose the first train heads east at 60 mph starting at station A, and the second train heads west at 40 mph starting at station B,  what distance apart?
#
# Suppose the problem is standard: Two trains are \( D \) miles apart and start at the same time moving towards each other at the given speeds.
#
# Without the initial distance \( D \), the fly's distance depends on \( D \).
#
# ---
#
# ### Final note:
#
# - If the initial distance \( D \) is given, bird's distance \( = \frac{9}{10} D \).
# - If no \( D \) is given, the problem is incomplete or misstated.
#
# ---
#
# ## Conclusion
#
# Since the problem as stated is inconsistent (trains starting at the same station but moving opposite ways never meet), the usual solution involves:
#
# - Finding the time it takes for trains to meet.
# - Calculating the bird's total distance by multiplying the bird's speed by this time.
#
# ---
#
# ### Let's summarize the general formula for the bird's travel distance:
#
# \[
# \boxed{
# \text{Total distance bird flies} = \text{Bird's speed} \times \text{Time until trains meet} = v_{\text{bird}} \times \frac{D}{v_1 + v_2}
# }
# \]
#
# where:
# - \( v_1 = 60 \) mph
# - \( v_2 = 40 \) mph
# - \( v_{\text{bird}} = 90 \) mph
# - \( D = \) initial distance between trains
#
# Thus, total distance bird flies =
#
# \[
# 90 \times \frac{D}{100} = \frac{9}{10} D
# \]
#
# ---
#
# If you provide the initial distance between the trains, I can give the exact numeric answer. Otherwise, the bird travels **90% of the initial distance** before the trains meet.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step.
#
# ### Given:
# - Two trains start from the same station at the same time.
# - Train A travels east at 60 mph.
# - Train B travels west at 40 mph.
# - A bird starts from the first train and flies toward the second train at 90 mph.
# - Each time the bird reaches a train, it instantly turns around and flies back toward the other train.
# - The bird continues flying back and forth until the two trains meet.
#
# ### Goal:
# Find the total distance the bird flies before the trains collide.
#
# ---
#
# ### Step 1: Find the time until the trains meet
#
# The trains are moving in opposite directions from the same point.
#
# - Relative speed of separation \( = 60 + 40 = 100 \text{ mph} \)
#
# Assuming the trains start at the same point (distance zero between them), but since they are moving apart, they will never collide if this was the setup. So, likely, the problem expects the trains to be **moving towards** each other, or the station represents the midpoint, and the trains move towards each other.
#
# But the problem states: "two trains **start from the same station at the same time**, one traveling east, other west."
#
# Normally if they move opposite directions from the same place, they move apart indefinitely and never meet.
#
# **It's likely the problem assumes the trains are moving towards each other starting at some distance apart.** Let me double-check the question:
#
# **The problem says:**
# > If two trains start from the same station at the same time, one traveling east at 60 mph and the other traveling west at 40 mph...
#
# Then the trains move away from each other and never meet.
#
# Is the problem possibly misstated?
#
# ---
#
# ### Common version of this problem:
#
# Two trains start at **different stations, \( D \) miles apart**, moving toward each other at speeds 60 mph and 40 mph. A bird flies back and forth in between at 90 mph.
#
# Given that the trains start \( D \) miles apart, the time until they meet is:
#
# \[
# t = \frac{D}{60 + 40} = \frac{D}{100} \text{ hours}
# \]
#
# The bird flies continuously at 90 mph during this time:
#
# \[
# \text{Distance bird flies} = 90 \times t = 90 \times \frac{D}{100} = \frac{9}{10} D
# \]
#
# ---
#
# ### So, the **key point here** is that the trains start from **different stations** a distance \( D \) apart.
#
# ---
#
# ### Summary:
#
# - Time until trains meet: \( t = \frac{D}{60 + 40} = \frac{D}{100} \) hours
# - Bird's speed: 90 mph
# - Bird's total distance: \( 90 \times t = \frac{9}{10} D \)
#
# ---
#
# ### Without the distance, we cannot get numerical value for bird's distance.
#
# ---
#
# ### Let's re-examine the question carefully:
#
# **Exact question:**
#
# > If two trains start from the same station at the same time, one traveling east at 60 mph and the other traveling west at 40 mph, a bird starts flying from the first train toward the second at 90 mph. When it reaches the second train, it instantly turns around and flies back to the first train, continuing this back-and-forth flight until the trains meet. How far does the bird travel before the trains collide?
#
# Because the trains start at the same station but go opposite directions at different speeds, they will never meet. Unless the problem means something else by "meet."
#
# ---
#
# ### Possible interpretation:
#
# Could it mean the trains start at the same station, but after some time, trains reverse direction and meet? Or a typo?
#
# Or maybe the bird flying towards the second train means the bird flies from eastbound train *behind* it to catch the other one moving west.
#
# ---
#
# ### **Alternative assumption:**
#
# If the trains move **toward each other**, suppose the first train heads east at 60 mph starting at station A, and the second train heads west at 40 mph starting at station B,  what distance apart?
#
# Suppose the problem is standard: Two trains are \( D \) miles apart and start at the same time moving towards each other at the given speeds.
#
# Without the initial distance \( D \), the fly's distance depends on \( D \).
#
# ---
#
# ### Final note:
#
# - If the initial distance \( D \) is given, bird's distance \( = \frac{9}{10} D \).
# - If no \( D \) is given, the problem is incomplete or misstated.
#
# ---
#
# ## Conclusion
#
# Since the problem as stated is inconsistent (trains starting at the same station but moving opposite ways never meet), the usual solution involves:
#
# - Finding the time it takes for trains to meet.
# - Calculating the bird's total distance by multiplying the bird's speed by this time.
#
# ---
#
# ### Let's summarize the general formula for the bird's travel distance:
#
# \[
# \boxed{
# \text{Total distance bird flies} = \text{Bird's speed} \times \text{Time until trains meet} = v_{\text{bird}} \times \frac{D}{v_1 + v_2}
# }
# \]
#
# where:
# - \( v_1 = 60 \) mph
# - \( v_2 = 40 \) mph
# - \( v_{\text{bird}} = 90 \) mph
# - \( D = \) initial distance between trains
#
# Thus, total distance bird flies =
#
# \[
# 90 \times \frac{D}{100} = \frac{9}{10} D
# \]
#
# ---
#
# If you provide the initial distance between the trains, I can give the exact numeric answer. Otherwise, the bird travels **90% of the initial distance** before the trains meet.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

question = "Please pick a business area that might be worth exploring for an Agentic AI opportunity."
print("\033[33mQuestion:\033[0m " + question)
messages = [{"role": "user", "content": question}]

# Then make the first call:

response = openai.chat.completions.create(
    model = "gpt-4.1-nano",
    messages = messages
)

# Then read the business idea:
answer = response.choices[0].message.content
display(Markdown(answer))
question = "Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution."
print("\n\033[33mQuestion:\033[0m " + question)
business_idea = "With: " + answer + " - Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution."
messages = [{"role": "user", "content": business_idea}]

# And repeat! In the next message, include the business idea within the message
response = openai.chat.completions.create(
    model = "gpt-4.1-nano",
    messages = messages
)

answer = response.choices[0].message.content
display(Markdown(answer))
question = "propose the Agentic AI solution."
print("\n\033[33mQuestion:\033[0m " + question)
propose_solution = "With: " + answer + " - propose the Agentic AI solution."
messages = [{"role": "user", "content": propose_solution}]

response = openai.chat.completions.create(
    model = "gpt-4.1-nano",
    messages = messages
)

answer = response.choices[0].message.content
print("Markdown final response:")
display(Markdown(answer))
# Out:
# Question: Please pick a business area that might be worth exploring for an Agentic AI opportunity.
# One promising business area for exploring Agentic AI opportunities is the **Personalized Healthcare Management** sector. This domain involves creating AI agents that can proactively assist individuals in managing their health, medication schedules, lifestyle choices, and wellness goals. An Agentic AI in this space could dynamically adapt recommendations based on real-time health data, engage users with personalized coaching, and coordinate with healthcare providers to improve outcomes—all while prioritizing privacy and ethical considerations. Given the growing emphasis on preventative care and digital health solutions, this area offers significant potential for impactful and innovative Agentic AI applications.
# Question: Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.
# A significant pain-point in the Personalized Healthcare Management sector is the challenge of maintaining consistent patient engagement and adherence to complex medication and lifestyle regimens. Patients often struggle with remembering to take medications on time, following personalized health advice, or staying motivated to pursue long-term wellness goals. This inconsistent adherence can lead to poorer health outcomes, increased hospitalizations, and higher healthcare costs.
#
# An Agentic AI solution could proactively monitor patient data in real-time, provide timely reminders, adjust recommendations dynamically based on the patient’s evolving condition, and offer personalized coaching that motivates sustained engagement. By seamlessly integrating with healthcare providers, it can also coordinate care plans and flag potential issues early, helping to bridge the gap between patients and their healthcare teams—addressing a critical challenge in achieving truly effective, personalized healthcare management.
# Question: propose the Agentic AI solution.
# Markdown final response:
# Proposed Agentic AI Solution for Personalized Healthcare Management: "HealthSync AI"
#
# Overview:
# HealthSync AI is an intelligent, proactive healthcare management agent designed to enhance patient engagement, adherence, and overall health outcomes by delivering personalized, real-time support. It seamlessly integrates with patients’ devices and healthcare providers’ systems to create a comprehensive, adaptive care ecosystem.
#
# Key Features:
#
# 1. Real-Time Monitoring & Data Integration
# - Continuously collects data from wearable devices, mobile apps, and healthcare records
# - Monitors vital signs, medication usage, activity levels, and other relevant health metrics
# - Detects deviations from personalized care plans promptly
#
# 2. Proactive Reminders & Dynamic Recommendations
# - Sends timely medication prompts and lifestyle advice tailored to the patient’s schedule and current health status
# - Adjusts recommendations dynamically based on ongoing data and recent trends
# - Offers motivational messages personalized to the patient's preferences and progress
#
# 3. Personalized Coaching & Engagement
# - Provides ongoing digital coaching through chat interfaces, videos, or interactive modules
# - Sets achievable short-term goals aligned with long-term wellness plans
# - Reinforces positive behaviors and addresses barriers to adherence
#
# 4. Care Coordination & Provider Integration
# - Shares summarized, actionable insights with healthcare teams
# - Flags potential issues such as missed medications, abnormal vitals, or increased risk factors
# - Facilitates teleconsultations or follow-up appointments when needed
#
# 5. Adaptive Learning & Continuous Improvement
# - Learns from individual patient responses to optimize engagement strategies
# - Updates the care plan recommendations based on new data and evolving health conditions
#
# Benefits:
# - Improves medication adherence and lifestyle compliance
# - Enhances patient motivation and confidence
# - Reduces unnecessary hospitalizations and healthcare costs
# - Strengthens the partnership between patients and providers
# - Supports truly personalized, effective healthcare management
#
# By proactively engaging patients through intelligent, personalized interventions and bridging gaps with healthcare providers, HealthSync AI addresses critical pain points in Personalized Healthcare Management, fostering better health outcomes and a more efficient healthcare system.
